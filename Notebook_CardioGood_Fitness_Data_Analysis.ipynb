# %% [markdown]
# <a href="https://colab.research.google.com/github/antonius-nugroho/CardioGood_Fitness/blob/main-indo/Notebook_CardioGood_Fitness_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Studi Kasus Perusahaan "CardioGood Fitness" - Statistik Deskriptif
# Sebuah tim pemasaran **AdRight** mendapatkan tugas untuk mengidetifikasi profil pelanggan yang unik untuk setiap produk *treadmill* yang ditawarkan oleh perusahaan **CardioGood Fitness**.
#
# Tim peneliti pemasaran memutuskan untuk menginvestigasi apakah ada perbedaan di antara lini produk terhadap karakteristik pelanggan.
#
# Tim pemasaran memutuskan untuk mengumpulkan data perorangan yang membeli sebuah *treadmill* di toko ritel **CardioGood Fitness** selama tiga bulan terakhir. Data disimpan di sebuah file yang diberi nama "CardioGoodFitness.csv".
#
# Dataset dapat didownload di:
# https://www.kaggle.com/datasets/saurav9786/cardiogoodfitness
#
# ### Tim Pemasaran mengidentifikasi variable pelanggan untuk penelitian sebagai berikut:
#   - product purchased: TM195, TM498, or TM798.
#   - gender: male / female
#   - age, in years.
#   - education, in years.
#   - relationship status: single / partnered.
#   - annual household income.
#   - average number of times the customer plans to use the treadmill each week.
#   - average number of miles the customer expects to walk/run each week.
#   - and self-rated fitness on a 1-to-5 scale, where 1 is poor shape and 5 is excellent shape.

# %% [markdown]
# ### Melakukan analisis deskriptif untuk membuat profil pelanggan terhadap setiap lini produk treadmil CardioGood Fitness

# %%
# Load the necessary packages
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the Cardio Dataset
mydata = pd.read_csv('/content/drive/MyDrive/Github Projects/Case Study - CardioGood Fitness Data Analysis/CardioGoodFitness.csv')

# %%
mydata.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
mydata.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

mydata.hist(figsize=(12,8))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Education'}>],
#        [<Axes: title={'center': 'Usage'}>,
#         <Axes: title={'center': 'Fitness'}>],
#        [<Axes: title={'center': 'Income'}>,
#         <Axes: title={'center': 'Miles'}>]], dtype=object)

# %%
import seaborn as sns #importing seaborn library

sns.boxplot(x="Gender", y="Age", data=mydata)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.boxplot(x="Product", y="Age", data=mydata)
# Out:
# <Axes: xlabel='Product', ylabel='Age'>

# %%
pd.crosstab(mydata['Product'],mydata['Gender'] )
# Out:
# Gender   Female  Male
# Product
# TM195        40    40
# TM498        29    31
# TM798         7    33

# %%
pd.crosstab(mydata['Product'],mydata['MaritalStatus'] )
# Out:
# MaritalStatus  Partnered  Single
# Product
# TM195                 48      32
# TM498                 36      24
# TM798                 23      17

# %%
sns.countplot(x="Product", hue="Gender", data=mydata)
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
pd.pivot_table(mydata, index=['Product', 'Gender'],
                     columns=[ 'MaritalStatus'], aggfunc=len)
# Out:
#                      Age        Education          Fitness           Income  \
# MaritalStatus  Partnered Single Partnered Single Partnered Single Partnered
# Product Gender
# TM195   Female        27     13        27     13        27     13        27
#         Male          21     19        21     19        21     19        21
# TM498   Female        15     14        15     14        15     14        15
#         Male          21     10        21     10        21     10        21
# TM798   Female         4      3         4      3         4      3         4
#         Male          19     14        19     14        19     14        19
#
#                           Miles            Usage
# MaritalStatus  Single Partnered Single Partnered Single
# Product Gender
# TM195   Female     13        27     13        27     13
#         Male       19        21     19        21     19
# TM498   Female     14        15     14        15     14
# ...

# %%
pd.pivot_table(mydata,'Income', index=['Product', 'Gender'],
                     columns=[ 'MaritalStatus'])
# Out:
# MaritalStatus      Partnered        Single
# Product Gender
# TM195   Female  46153.777778  45742.384615
#         Male    50028.000000  43265.842105
# TM498   Female  49724.800000  48920.357143
#         Male    49378.285714  47071.800000
# TM798   Female  84972.250000  58516.000000
#         Male    81431.368421  68216.428571

# %%
pd.pivot_table(mydata,'Miles', index=['Product', 'Gender'],
                     columns=[ 'MaritalStatus'])
# Out:
# MaritalStatus    Partnered      Single
# Product Gender
# TM195   Female   74.925926   78.846154
#         Male     80.190476   99.526316
# TM498   Female   94.000000   80.214286
#         Male     87.238095   91.100000
# TM798   Female  215.000000  133.333333
#         Male    176.315789  147.571429

# %%
sns.pairplot(mydata)

# %%
mydata['Age'].std()
# Out:
# 6.943498135399795

# %%
mydata['Age'].mean()
# Out:
# 28.788888888888888

# %%
sns.displot(data=mydata, x='Age', kde=True)

# %%
mydata.hist(by='Gender',column = 'Age')
# Out:
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
mydata.hist(by='Gender',column = 'Income', figsize=(10,3))
# Out:
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
mydata.hist(by='Gender',column = 'Miles', figsize=(10,3))
# Out:
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
mydata.hist(by='Product',column = 'Miles', sharey=False, figsize=(10,5))
# Out:
# array([[<Axes: title={'center': 'TM195'}>,
#         <Axes: title={'center': 'TM498'}>],
#        [<Axes: title={'center': 'TM798'}>, <Axes: >]], dtype=object)

# %%
mydata
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
corr = mydata.corr(method='pearson', numeric_only=True)
corr
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
# Simple Linear Regression

#Load function from sklearn
from sklearn import linear_model

# Create linear regression object
regr = linear_model.LinearRegression()

y = mydata['Miles']
x = mydata[['Usage','Fitness']]

# Train the model using the training sets
regr.fit(x,y)
# Out:
# LinearRegression()

# %%
regr.coef_
# Out:
# array([20.21486334, 27.20649954])

# %%
regr.intercept_
# Out:
# -56.74288178464862

# %%
# MilesPredicted = -56.74 + 20.21*Usage + 27.20*Fitness
